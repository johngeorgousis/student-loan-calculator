# %% [markdown]
# # Student Loan Calculator
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Function

# %%
def balance(years=10, init=30000., r = 0.06, n=12, frequency = 'annually'):
    
    '''
    Prints your balance and added interest for each year/month after years
    
    years: number of years to be printed, default=10
    init: initial amount of money (initial principal balance), default=30000
    r: interest rate per year, default=0.06
    n: compounding in a year, default=12 (monthly compounding)
    frequency: 'monthly' prints values for each month, 'annually' prints values for each year
    
    RETURNS: list of values for interest, balance each month for monthly and each year for annually
    '''
    
    
    if frequency == 'annually':
        # Define compounding interest function for t in years
        def y(t):
            return init*(1+r/n)**(n*t) 

        interest = []
        balance = [init]

        print('Initial Balance: ', init)
        print('\n')

        for i in range(1, years):
            print('Year {} interest added: {}'.format(i, int(y(i) - y(i-1))))
            print('Start of year {} balance: {}'.format(i+1, int(y(i))))
            print('\n')

            interest.append(y(i) - y(i-1))
            balance.append(y(i))

        
        print('Total interest added: {}'.format(int(sum(interest))))
        print('\n')

        # Plotting Results
        plt.plot(range(years), balance)
        plt.ylabel('Balance')
        plt.xlabel('Years')
        plt.show()
        
        plt.plot(range(years-1), interest)
        plt.ylabel('Interest')
        plt.xlabel('Years')
        plt.show()
        
        return interest, balance
    
    
    
    elif frequency == 'monthly':
        # Define compounding interest function for t in months
        def y(t):
            return init*(1+(r/12)/(n/12))**((n/12)*t) 

        interest = []
        balance = [init]
        a = 0

        print('Initial Balance: {}{}'.format(init, u"\xA3"))
        print('\n')
        print('------------------------------------------------Year 1')

        for i in range(1, years*12):
            a += 1
            if a%12 == 0:
                print('------------------------------------------------Year {}'.format(a//12 + 1))
                a = 0
            if a == 0:
                print('Month {} interest added: {}{}'.format(12, int(y(i) - y(i-1)), u"\xA3"))
            else:
                print('Month {} interest added: {}{}'.format(a, int(y(i) - y(i-1)), u"\xA3"))
                
            print('Start of Month {} balance: {}{}'.format(a + 1, int(y(i)), u"\xA3"))
            print('-')

            interest.append(y(i) - y(i-1))
            balance.append(y(i))
            
        # Plotting Results
        plt.plot(range(years*12), balance)
        plt.ylabel('Balance')
        plt.xlabel('Months')
        plt.show()
        
        plt.plot(range(years*12-1), interest)
        plt.ylabel('Interest')
        plt.xlabel('Months')
        plt.show()


        print('Total interest added: {}'.format(sum(interest)))
        return interest, balance

# %%
balance(3,init = 19600,  frequency = 'monthly')

f=1
# Out:
# Initial Balance: 19600£
#
#
# ------------------------------------------------Year 1
# Month 1 interest added: 97£
# Start of Month 2 balance: 19697£
# -
# Month 2 interest added: 98£
# Start of Month 3 balance: 19796£
# -
# Month 3 interest added: 98£
# Start of Month 4 balance: 19895£
# -
# Month 4 interest added: 99£
# Start of Month 5 balance: 19994£
# -
# Month 5 interest added: 99£
# Start of Month 6 balance: 20094£
# -
# Month 6 interest added: 100£
# Start of Month 7 balance: 20195£
# -
# Month 7 interest added: 100£
# Start of Month 8 balance: 20296£
# -
# Month 8 interest added: 101£
# Start of Month 9 balance: 20397£
# -
# Month 9 interest added: 101£
# Start of Month 10 balance: 20499£
# -
# Month 10 interest added: 102£
# Start of Month 11 balance: 20602£
# -
# Month 11 interest added: 103£
# Start of Month 12 balance: 20705£
# -
# ------------------------------------------------Year 2
# Month 12 interest added: 103£
# Start of Month 1 balance: 20808£
# -
# Month 1 interest added: 104£
# Start of Month 2 balance: 20912£
# -
# Month 2 interest added: 104£
# Start of Month 3 balance: 21017£
# -
# Month 3 interest added: 105£
# Start of Month 4 balance: 21122£
# -
# Month 4 interest added: 105£
# Start of Month 5 balance: 21228£
# -
# Month 5 interest added: 106£
# Start of Month 6 balance: 21334£
# -
# Month 6 interest added: 106£
# Start of Month 7 balance: 21441£
# -
# Month 7 interest added: 107£
# Start of Month 8 balance: 21548£
# -
# Month 8 interest added: 107£
# Start of Month 9 balance: 21655£
# -
# Month 9 interest added: 108£
# Start of Month 10 balance: 21764£
# -
# Month 10 interest added: 108£
# Start of Month 11 balance: 21873£
# -
# Month 11 interest added: 109£
# Start of Month 12 balance: 21982£
# -
# ------------------------------------------------Year 2
# Month 12 interest added: 109£
# Start of Month 1 balance: 22092£
# -
# Month 1 interest added: 110£
# Start of Month 2 balance: 22202£
# -
# Month 2 interest added: 111£
# Start of Month 3 balance: 22313£
# -
# Month 3 interest added: 111£
# Start of Month 4 balance: 22425£
# -
# Month 4 interest added: 112£
# Start of Month 5 balance: 22537£
# -
# Month 5 interest added: 112£
# Start of Month 6 balance: 22650£
# -
# Month 6 interest added: 113£
# Start of Month 7 balance: 22763£
# -
# Month 7 interest added: 113£
# Start of Month 8 balance: 22877£
# -
# Month 8 interest added: 114£
# Start of Month 9 balance: 22991£
# -
# Month 9 interest added: 114£
# Start of Month 10 balance: 23106£
# -
# Month 10 interest added: 115£
# Start of Month 11 balance: 23222£
# -
# Month 11 interest added: 116£
# Start of Month 12 balance: 23338£
# -
# Total interest added: 3738.2470512825203

# %%
balance_monthly(10 ,init = 19600,  frequency = 'annually')
# Out:
# Initial Balance:  19600
#
#
# Year 1 interest added: 1208
# Start of year 2 balance: 20808
#
#
# Year 2 interest added: 1283
# Start of year 3 balance: 22092
#
#
# Year 3 interest added: 1362
# Start of year 4 balance: 23454
#
#
# Year 4 interest added: 1446
# Start of year 5 balance: 24901
#
#
# Year 5 interest added: 1535
# Start of year 6 balance: 26437
#
#
# Year 6 interest added: 1630
# Start of year 7 balance: 28068
#
#
# Year 7 interest added: 1731
# Start of year 8 balance: 29799
#
#
# Year 8 interest added: 1837
# Start of year 9 balance: 31637
#
#
# Year 9 interest added: 1951
# Start of year 10 balance: 33588
#
#
# Total interest added: 13988
# ([1208.8851125441652,
#   1283.4465010814565,
#   1362.6066729133054,
#   1446.6492709305676,
#   1535.875432496934,
#   1630.6048684697816,
#   1731.1770087725963,
#   1837.952218623821,
#   1951.313089780033],
#  [19600,
#   20808.885112544165,
#   22092.33161362562,
#   23454.938286538927,
#   24901.587557469495,
#   26437.46298996643,
#   28068.06785843621,
#   29799.244867208807,
#   31637.197085832628,
#   33588.51017561266])

# %% [markdown]
# ## Examples

# %%
balance_monthly(2,init = 19500,  frequency = 'monthly')

b=1
# Out:
# Initial Balance: 19500£
#
#
# ------------------------------------------------Year 1
# Month 1 interest added: 97£
# Start of Month 2 balance: 19597£
# -
# Month 2 interest added: 97£
# Start of Month 3 balance: 19695£
# -
# Month 3 interest added: 98£
# Start of Month 4 balance: 19793£
# -
# Month 4 interest added: 98£
# Start of Month 5 balance: 19892£
# -
# Month 5 interest added: 99£
# Start of Month 6 balance: 19992£
# -
# Month 6 interest added: 99£
# Start of Month 7 balance: 20092£
# -
# Month 7 interest added: 100£
# Start of Month 8 balance: 20192£
# -
# Month 8 interest added: 100£
# Start of Month 9 balance: 20293£
# -
# Month 9 interest added: 101£
# Start of Month 10 balance: 20395£
# -
# Month 10 interest added: 101£
# Start of Month 11 balance: 20497£
# -
# Month 11 interest added: 102£
# Start of Month 12 balance: 20599£
# -
# ------------------------------------------------Year 2
# Month 12 interest added: 102£
# Start of Month 1 balance: 20702£
# -
# Month 1 interest added: 103£
# Start of Month 2 balance: 20806£
# -
# Month 2 interest added: 104£
# Start of Month 3 balance: 20910£
# -
# Month 3 interest added: 104£
# Start of Month 4 balance: 21014£
# -
# Month 4 interest added: 105£
# Start of Month 5 balance: 21119£
# -
# Month 5 interest added: 105£
# Start of Month 6 balance: 21225£
# -
# Month 6 interest added: 106£
# Start of Month 7 balance: 21331£
# -
# Month 7 interest added: 106£
# Start of Month 8 balance: 21438£
# -
# Month 8 interest added: 107£
# Start of Month 9 balance: 21545£
# -
# Month 9 interest added: 107£
# Start of Month 10 balance: 21653£
# -
# Month 10 interest added: 108£
# Start of Month 11 balance: 21761£
# -
# Month 11 interest added: 108£
# Start of Month 12 balance: 21870£
# -
# Total interest added: 2370.2643144329195

# %%
balance_monthly(10 ,init = 19600,  frequency = 'annually')

c=1
# Out:
# Initial Balance:  19600
#
#
# Year 1 interest added: 1208
# Start of year 2 balance: 20808
#
#
# Year 2 interest added: 1283
# Start of year 3 balance: 22092
#
#
# Year 3 interest added: 1362
# Start of year 4 balance: 23454
#
#
# Year 4 interest added: 1446
# Start of year 5 balance: 24901
#
#
# Year 5 interest added: 1535
# Start of year 6 balance: 26437
#
#
# Year 6 interest added: 1630
# Start of year 7 balance: 28068
#
#
# Year 7 interest added: 1731
# Start of year 8 balance: 29799
#
#
# Year 8 interest added: 1837
# Start of year 9 balance: 31637
#
#
# Year 9 interest added: 1951
# Start of year 10 balance: 33588
#
#
# Total interest added: 13988

# %%
balance_monthly(5,init = 19600,  frequency = 'annually')

d=1
# Out:
# Initial Balance:  19600
#
#
# Year 1 interest added: 1208
# Start of year 2 balance: 20808
#
#
# Year 2 interest added: 1283
# Start of year 3 balance: 22092
#
#
# Year 3 interest added: 1362
# Start of year 4 balance: 23454
#
#
# Year 4 interest added: 1446
# Start of year 5 balance: 24901
#
#
# Total interest added: 5301

# %%
print('If you repay in year 5 instead of year 10 you will save {} pounds!'.format(13988 - 5301))
# Out:
# If you repay in year 5 instead of year 10 you will save 8687 pounds!
